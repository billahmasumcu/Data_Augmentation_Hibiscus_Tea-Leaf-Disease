# %%
# prompt: mount

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# ==========================================
# ✅ Tea Leaf Augmentation Script (Fixed)
# ==========================================
import os
import random
import time
import numpy as np
import cv2
from PIL import Image, ImageEnhance

# --- Google Drive Path Configuration ---
source_folder = r"/content/drive/MyDrive/Tea Augmentation/Tea Algal Spot"
target_folder = r"/content/drive/MyDrive/Tea Augmentation/Tea Algal Spotoutput"
target_images = 1000

# --- Ensure Target Folder Exists ---
os.makedirs(target_folder, exist_ok=True)

# --- PIL-Based Augmentation ---
def augment_image_pil(image, count):
    brightness_factor = random.uniform(0.7, 1.3)
    contrast_factor = random.uniform(0.7, 1.3)
    color_factor = random.uniform(0.7, 1.3)

    enhanced_image = ImageEnhance.Color(
        ImageEnhance.Contrast(
            ImageEnhance.Brightness(image).enhance(brightness_factor)
        ).enhance(contrast_factor)
    ).enhance(color_factor)

    filename = f"aug_pil_{count}_b{brightness_factor:.2f}_c{contrast_factor:.2f}_col{color_factor:.2f}.jpg"
    return enhanced_image, filename

# --- OpenCV-Based Augmentation ---
def augment_image_cv2(image_path, count):
    image = cv2.imread(image_path)
    if image is None:
        raise ValueError(f"Could not read image: {image_path}")

    height, width = image.shape[:2]
    augmented_images = []

    # Center Crops
    for crop_ratio in [0.8, 0.6]:
        crop_h, crop_w = int(height * crop_ratio), int(width * crop_ratio)
        start_x, start_y = (width - crop_w) // 2, (height - crop_h) // 2
        cropped = image[start_y:start_y + crop_h, start_x:start_x + crop_w]
        resized = cv2.resize(cropped, (width, height), interpolation=cv2.INTER_AREA)
        filename = f"cv2_crop_{crop_ratio}_{count}.jpg"
        augmented_images.append((resized, filename))

    # Center Scaling
    for scale in [1.1, 1.3]:
        scaled_h, scaled_w = int(height * scale), int(width * scale)
        scaled = cv2.resize(image, (scaled_w, scaled_h), interpolation=cv2.INTER_LINEAR)
        crop_y = (scaled_h - height) // 2
        crop_x = (scaled_w - width) // 2
        cropped = scaled[crop_y:crop_y + height, crop_x:crop_x + width]
        filename = f"cv2_scale_{scale}_{count}.jpg"
        augmented_images.append((cropped, filename))

    # Flip
    augmented_images.append((cv2.flip(image, 1), f"cv2_flip_h_{count}.jpg"))
    augmented_images.append((cv2.flip(image, 0), f"cv2_flip_v_{count}.jpg"))

    # Rotation
    for angle in [15, -15, 30, -30]:
        M = cv2.getRotationMatrix2D((width // 2, height // 2), angle, 1)
        rotated = cv2.warpAffine(image, M, (width, height), flags=cv2.INTER_LINEAR)
        filename = f"cv2_rotate_{angle}_{count}.jpg"
        augmented_images.append((rotated, filename))

    # Shifting
    for dx, dy in [(10, 0), (-10, 0), (0, 10), (0, -10)]:
        M = np.float32([[1, 0, dx], [0, 1, dy]])
        shifted = cv2.warpAffine(image, M, (width, height), flags=cv2.INTER_LINEAR)
        filename = f"cv2_shift_{dx}_{dy}_{count}.jpg"
        augmented_images.append((shifted, filename))

    # Zoom (random zoom in/out between 0.8 to 1.2)
    for zoom_factor in [0.8, 1.0, 1.2]:
        if zoom_factor == 1.0:
            zoomed = image.copy()
        elif zoom_factor > 1.0:
            zh, zw = int(height * zoom_factor), int(width * zoom_factor)
            zoomed_large = cv2.resize(image, (zw, zh), interpolation=cv2.INTER_LINEAR)
            start_x, start_y = (zw - width) // 2, (zh - height) // 2
            zoomed = zoomed_large[start_y:start_y + height, start_x:start_x + width]
        else:
            zh, zw = int(height * zoom_factor), int(width * zoom_factor)
            zoomed_small = cv2.resize(image, (zw, zh), interpolation=cv2.INTER_LINEAR)
            zoomed = np.zeros_like(image)
            start_x, start_y = (width - zw) // 2, (height - zh) // 2
            zoomed[start_y:start_y + zh, start_x:start_x + zw] = zoomed_small

        filename = f"cv2_zoom_{zoom_factor}_{count}.jpg"
        augmented_images.append((zoomed, filename))

    # Noisy
    mean, stddev = 0, 10
    noise = np.random.normal(mean, stddev, image.shape).astype(np.float32)
    noisy_image = image.astype(np.float32) + noise
    noisy_image = np.clip(noisy_image, 0, 255).astype(np.uint8)
    filename = f"cv2_noisy_{count}.jpg"
    augmented_images.append((noisy_image, filename))

    # Brightness
    for brightness_factor in [0.7, 1.3]:
        bright_img = cv2.convertScaleAbs(image, alpha=brightness_factor, beta=0)
        filename = f"cv2_brightness_{brightness_factor}_{count}.jpg"
        augmented_images.append((bright_img, filename))

    return augmented_images

# --- Manage Max Number of Images ---
def manage_target_folder(folder, max_images):
    images = sorted(
        [f for f in os.listdir(folder) if f.lower().endswith(('.jpg', '.jpeg', '.png'))],
        key=lambda x: os.path.getctime(os.path.join(folder, x))
    )
    if len(images) > max_images:
        for img in images[max_images:]:
            os.remove(os.path.join(folder, img))

# --- Main Process ---
def main():
    print("🔍 Checking source folder...")
    if not os.path.isdir(source_folder):
        print(f"❌ Source folder not found: {source_folder}")
        return
    else:
        print(f"✅ Source folder found: {source_folder}")

    # List files
    files_in_source = os.listdir(source_folder)
    print(f"📂 Files found: {len(files_in_source)}")
    if files_in_source:
        print("🔸 First few files:", files_in_source[:5])

    image_paths = [
        os.path.join(source_folder, f)
        for f in files_in_source
        if f.lower().endswith(('.jpg', '.jpeg', '.png'))
    ]

    if not image_paths:
        print("⚠️ No valid image files (.jpg/.jpeg/.png) found in source folder.")
        return
    else:
        print(f"✅ Found {len(image_paths)} valid image(s) for augmentation.")

    random.shuffle(image_paths)

    start_time = time.time()
    current_count = len(os.listdir(target_folder))
    print(f"🚀 Starting augmentation. Already in target: {current_count} images.")

    while current_count < target_images:
        for img_path in image_paths:
            if current_count >= target_images:
                break
            try:
                with Image.open(img_path) as pil_image:
                    if pil_image.mode != "RGB":
                        pil_image = pil_image.convert("RGB")

                    pil_aug, pil_filename = augment_image_pil(pil_image, current_count)
                    pil_aug.save(os.path.join(target_folder, pil_filename), format="JPEG")
                    print(f"✅ Saved PIL image: {pil_filename}")
                    current_count += 1

                cv2_augments = augment_image_cv2(img_path, current_count)
                for aug_img, filename in cv2_augments:
                    if current_count >= target_images:
                        break
                    cv2.imwrite(os.path.join(target_folder, filename), aug_img)
                    print(f"✅ Saved CV2 image: {filename}")
                    current_count += 1

            except Exception as e:
                print(f"⚠️ Error processing {img_path}: {e}")

    manage_target_folder(target_folder, target_images)
    total = len(os.listdir(target_folder))
    print(f"\n✅ Augmentation complete. Total images: {total}")
    print(f"⏱ Time taken: {time.time() - start_time:.2f} seconds")

# --- Run ---
if __name__ == "__main__":
    main()
# Out:
# 🔍 Checking source folder...
# ✅ Source folder found: /content/drive/MyDrive/Tea Augmentation/Tea Algal Spot
# 📂 Files found: 54
# 🔸 First few files: ['71.png', '_DSC7791.png', '_DSC7795.png', '_DSC7785.png', '65.png']
# ✅ Found 54 valid image(s) for augmentation.
# 🚀 Starting augmentation. Already in target: 0 images.
# ✅ Saved PIL image: aug_pil_0_b1.17_c0.88_col0.86.jpg
# ✅ Saved CV2 image: cv2_crop_0.8_1.jpg
# ✅ Saved CV2 image: cv2_crop_0.6_1.jpg
# ✅ Saved CV2 image: cv2_scale_1.1_1.jpg
# ✅ Saved CV2 image: cv2_scale_1.3_1.jpg
# ✅ Saved CV2 image: cv2_flip_h_1.jpg
# ✅ Saved CV2 image: cv2_flip_v_1.jpg
# ✅ Saved CV2 image: cv2_rotate_15_1.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_1.jpg
# ✅ Saved CV2 image: cv2_rotate_30_1.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_1.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_1.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_1.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_1.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_1.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_1.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_1.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_1.jpg
# ✅ Saved CV2 image: cv2_noisy_1.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_1.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_1.jpg
# ✅ Saved PIL image: aug_pil_21_b1.21_c1.15_col0.87.jpg
# ✅ Saved CV2 image: cv2_crop_0.8_22.jpg
# ✅ Saved CV2 image: cv2_crop_0.6_22.jpg
# ✅ Saved CV2 image: cv2_scale_1.1_22.jpg
# ✅ Saved CV2 image: cv2_scale_1.3_22.jpg
# ✅ Saved CV2 image: cv2_flip_h_22.jpg
# ✅ Saved CV2 image: cv2_flip_v_22.jpg
# ✅ Saved CV2 image: cv2_rotate_15_22.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_22.jpg
# ✅ Saved CV2 image: cv2_rotate_30_22.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_22.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_22.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_22.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_22.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_22.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_22.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_22.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_22.jpg
# ✅ Saved CV2 image: cv2_noisy_22.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_22.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_22.jpg
# ✅ Saved PIL image: aug_pil_42_b0.88_c0.81_col1.14.jpg
# ✅ Saved CV2 image: cv2_crop_0.8_43.jpg
# ✅ Saved CV2 image: cv2_crop_0.6_43.jpg
# ✅ Saved CV2 image: cv2_scale_1.1_43.jpg
# ✅ Saved CV2 image: cv2_scale_1.3_43.jpg
# ✅ Saved CV2 image: cv2_flip_h_43.jpg
# ✅ Saved CV2 image: cv2_flip_v_43.jpg
# ✅ Saved CV2 image: cv2_rotate_15_43.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_43.jpg
# ✅ Saved CV2 image: cv2_rotate_30_43.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_43.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_43.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_43.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_43.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_43.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_43.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_43.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_43.jpg
# ✅ Saved CV2 image: cv2_noisy_43.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_43.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_43.jpg
# ✅ Saved PIL image: aug_pil_63_b1.27_c0.84_col0.75.jpg
# ✅ Saved CV2 image: cv2_crop_0.8_64.jpg
# ✅ Saved CV2 image: cv2_crop_0.6_64.jpg
# ✅ Saved CV2 image: cv2_scale_1.1_64.jpg
# ✅ Saved CV2 image: cv2_scale_1.3_64.jpg
# ✅ Saved CV2 image: cv2_flip_h_64.jpg
# ✅ Saved CV2 image: cv2_flip_v_64.jpg
# ✅ Saved CV2 image: cv2_rotate_15_64.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_64.jpg
# ✅ Saved CV2 image: cv2_rotate_30_64.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_64.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_64.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_64.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_64.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_64.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_64.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_64.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_64.jpg
# ✅ Saved CV2 image: cv2_noisy_64.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_64.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_64.jpg
# ✅ Saved PIL image: aug_pil_84_b0.74_c1.29_col1.12.jpg
# ✅ Saved CV2 image: cv2_crop_0.8_85.jpg
# ✅ Saved CV2 image: cv2_crop_0.6_85.jpg
# ✅ Saved CV2 image: cv2_scale_1.1_85.jpg
# ✅ Saved CV2 image: cv2_scale_1.3_85.jpg
# ✅ Saved CV2 image: cv2_flip_h_85.jpg
# ✅ Saved CV2 image: cv2_flip_v_85.jpg
# ✅ Saved CV2 image: cv2_rotate_15_85.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_85.jpg
# ✅ Saved CV2 image: cv2_rotate_30_85.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_85.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_85.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_85.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_85.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_85.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_85.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_85.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_85.jpg
# ✅ Saved CV2 image: cv2_noisy_85.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_85.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_85.jpg
# ✅ Saved PIL image: aug_pil_105_b1.24_c0.87_col0.93.jpg
# ✅ Saved CV2 image: cv2_crop_0.8_106.jpg
# ✅ Saved CV2 image: cv2_crop_0.6_106.jpg
# ✅ Saved CV2 image: cv2_scale_1.1_106.jpg
# ✅ Saved CV2 image: cv2_scale_1.3_106.jpg
# ✅ Saved CV2 image: cv2_flip_h_106.jpg
# ✅ Saved CV2 image: cv2_flip_v_106.jpg
# ✅ Saved CV2 image: cv2_rotate_15_106.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_106.jpg
# ✅ Saved CV2 image: cv2_rotate_30_106.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_106.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_106.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_106.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_106.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_106.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_106.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_106.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_106.jpg
# ✅ Saved CV2 image: cv2_noisy_106.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_106.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_106.jpg
# ✅ Saved PIL image: aug_pil_126_b0.76_c1.27_col0.75.jpg
# ✅ Saved CV2 image: cv2_crop_0.8_127.jpg
# ✅ Saved CV2 image: cv2_crop_0.6_127.jpg
# ✅ Saved CV2 image: cv2_scale_1.1_127.jpg
# ✅ Saved CV2 image: cv2_scale_1.3_127.jpg
# ✅ Saved CV2 image: cv2_flip_h_127.jpg
# ✅ Saved CV2 image: cv2_flip_v_127.jpg
# ✅ Saved CV2 image: cv2_rotate_15_127.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_127.jpg
# ✅ Saved CV2 image: cv2_rotate_30_127.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_127.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_127.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_127.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_127.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_127.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_127.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_127.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_127.jpg
# ✅ Saved CV2 image: cv2_noisy_127.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_127.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_127.jpg
# ✅ Saved PIL image: aug_pil_147_b1.22_c0.76_col0.94.jpg
# ✅ Saved CV2 image: cv2_crop_0.8_148.jpg
# ✅ Saved CV2 image: cv2_crop_0.6_148.jpg
# ✅ Saved CV2 image: cv2_scale_1.1_148.jpg
# ✅ Saved CV2 image: cv2_scale_1.3_148.jpg
# ✅ Saved CV2 image: cv2_flip_h_148.jpg
# ✅ Saved CV2 image: cv2_flip_v_148.jpg
# ✅ Saved CV2 image: cv2_rotate_15_148.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_148.jpg
# ✅ Saved CV2 image: cv2_rotate_30_148.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_148.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_148.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_148.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_148.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_148.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_148.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_148.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_148.jpg
# ✅ Saved CV2 image: cv2_noisy_148.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_148.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_148.jpg
# ✅ Saved PIL image: aug_pil_168_b1.06_c1.18_col1.18.jpg
# ✅ Saved CV2 image: cv2_crop_0.8_169.jpg
# ✅ Saved CV2 image: cv2_crop_0.6_169.jpg
# ✅ Saved CV2 image: cv2_scale_1.1_169.jpg
# ✅ Saved CV2 image: cv2_scale_1.3_169.jpg
# ✅ Saved CV2 image: cv2_flip_h_169.jpg
# ✅ Saved CV2 image: cv2_flip_v_169.jpg
# ✅ Saved CV2 image: cv2_rotate_15_169.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_169.jpg
# ✅ Saved CV2 image: cv2_rotate_30_169.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_169.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_169.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_169.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_169.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_169.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_169.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_169.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_169.jpg
# ✅ Saved CV2 image: cv2_noisy_169.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_169.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_169.jpg
# ✅ Saved PIL image: aug_pil_189_b0.76_c0.71_col1.24.jpg
# ✅ Saved CV2 image: cv2_crop_0.8_190.jpg
# ✅ Saved CV2 image: cv2_crop_0.6_190.jpg
# ✅ Saved CV2 image: cv2_scale_1.1_190.jpg
# ✅ Saved CV2 image: cv2_scale_1.3_190.jpg
# ✅ Saved CV2 image: cv2_flip_h_190.jpg
# ✅ Saved CV2 image: cv2_flip_v_190.jpg
# ✅ Saved CV2 image: cv2_rotate_15_190.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_190.jpg
# ✅ Saved CV2 image: cv2_rotate_30_190.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_190.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_190.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_190.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_190.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_190.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_190.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_190.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_190.jpg
# ✅ Saved CV2 image: cv2_noisy_190.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_190.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_190.jpg
# ✅ Saved PIL image: aug_pil_210_b1.16_c0.99_col0.71.jpg
# ✅ Saved CV2 image: cv2_crop_0.8_211.jpg
# ✅ Saved CV2 image: cv2_crop_0.6_211.jpg
# ✅ Saved CV2 image: cv2_scale_1.1_211.jpg
# ✅ Saved CV2 image: cv2_scale_1.3_211.jpg
# ✅ Saved CV2 image: cv2_flip_h_211.jpg
# ✅ Saved CV2 image: cv2_flip_v_211.jpg
# ✅ Saved CV2 image: cv2_rotate_15_211.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_211.jpg
# ✅ Saved CV2 image: cv2_rotate_30_211.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_211.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_211.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_211.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_211.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_211.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_211.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_211.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_211.jpg
# ✅ Saved CV2 image: cv2_noisy_211.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_211.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_211.jpg
# ✅ Saved PIL image: aug_pil_231_b1.14_c1.09_col0.71.jpg
# ✅ Saved CV2 image: cv2_crop_0.8_232.jpg
# ✅ Saved CV2 image: cv2_crop_0.6_232.jpg
# ✅ Saved CV2 image: cv2_scale_1.1_232.jpg
# ✅ Saved CV2 image: cv2_scale_1.3_232.jpg
# ✅ Saved CV2 image: cv2_flip_h_232.jpg
# ✅ Saved CV2 image: cv2_flip_v_232.jpg
# ✅ Saved CV2 image: cv2_rotate_15_232.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_232.jpg
# ✅ Saved CV2 image: cv2_rotate_30_232.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_232.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_232.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_232.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_232.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_232.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_232.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_232.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_232.jpg
# ✅ Saved CV2 image: cv2_noisy_232.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_232.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_232.jpg
# ✅ Saved PIL image: aug_pil_252_b0.99_c0.75_col0.81.jpg
# ✅ Saved CV2 image: cv2_crop_0.8_253.jpg
# ✅ Saved CV2 image: cv2_crop_0.6_253.jpg
# ✅ Saved CV2 image: cv2_scale_1.1_253.jpg
# ✅ Saved CV2 image: cv2_scale_1.3_253.jpg
# ✅ Saved CV2 image: cv2_flip_h_253.jpg
# ✅ Saved CV2 image: cv2_flip_v_253.jpg
# ✅ Saved CV2 image: cv2_rotate_15_253.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_253.jpg
# ✅ Saved CV2 image: cv2_rotate_30_253.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_253.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_253.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_253.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_253.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_253.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_253.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_253.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_253.jpg
# ✅ Saved CV2 image: cv2_noisy_253.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_253.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_253.jpg
# ✅ Saved PIL image: aug_pil_273_b0.77_c1.15_col1.01.jpg
# ✅ Saved CV2 image: cv2_crop_0.8_274.jpg
# ✅ Saved CV2 image: cv2_crop_0.6_274.jpg
# ✅ Saved CV2 image: cv2_scale_1.1_274.jpg
# ✅ Saved CV2 image: cv2_scale_1.3_274.jpg
# ✅ Saved CV2 image: cv2_flip_h_274.jpg
# ✅ Saved CV2 image: cv2_flip_v_274.jpg
# ✅ Saved CV2 image: cv2_rotate_15_274.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_274.jpg
# ✅ Saved CV2 image: cv2_rotate_30_274.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_274.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_274.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_274.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_274.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_274.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_274.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_274.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_274.jpg
# ✅ Saved CV2 image: cv2_noisy_274.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_274.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_274.jpg
# ✅ Saved PIL image: aug_pil_294_b1.08_c0.75_col1.17.jpg
# ✅ Saved CV2 image: cv2_crop_0.8_295.jpg
# ✅ Saved CV2 image: cv2_crop_0.6_295.jpg
# ✅ Saved CV2 image: cv2_scale_1.1_295.jpg
# ✅ Saved CV2 image: cv2_scale_1.3_295.jpg
# ✅ Saved CV2 image: cv2_flip_h_295.jpg
# ✅ Saved CV2 image: cv2_flip_v_295.jpg
# ✅ Saved CV2 image: cv2_rotate_15_295.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_295.jpg
# ✅ Saved CV2 image: cv2_rotate_30_295.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_295.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_295.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_295.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_295.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_295.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_295.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_295.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_295.jpg
# ✅ Saved CV2 image: cv2_noisy_295.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_295.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_295.jpg
# ✅ Saved PIL image: aug_pil_315_b0.78_c1.21_col1.09.jpg
# ✅ Saved CV2 image: cv2_crop_0.8_316.jpg
# ✅ Saved CV2 image: cv2_crop_0.6_316.jpg
# ✅ Saved CV2 image: cv2_scale_1.1_316.jpg
# ✅ Saved CV2 image: cv2_scale_1.3_316.jpg
# ✅ Saved CV2 image: cv2_flip_h_316.jpg
# ✅ Saved CV2 image: cv2_flip_v_316.jpg
# ✅ Saved CV2 image: cv2_rotate_15_316.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_316.jpg
# ✅ Saved CV2 image: cv2_rotate_30_316.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_316.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_316.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_316.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_316.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_316.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_316.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_316.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_316.jpg
# ✅ Saved CV2 image: cv2_noisy_316.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_316.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_316.jpg
# ✅ Saved PIL image: aug_pil_336_b1.29_c0.84_col0.72.jpg
# ✅ Saved CV2 image: cv2_crop_0.8_337.jpg
# ✅ Saved CV2 image: cv2_crop_0.6_337.jpg
# ✅ Saved CV2 image: cv2_scale_1.1_337.jpg
# ✅ Saved CV2 image: cv2_scale_1.3_337.jpg
# ✅ Saved CV2 image: cv2_flip_h_337.jpg
# ✅ Saved CV2 image: cv2_flip_v_337.jpg
# ✅ Saved CV2 image: cv2_rotate_15_337.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_337.jpg
# ✅ Saved CV2 image: cv2_rotate_30_337.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_337.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_337.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_337.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_337.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_337.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_337.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_337.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_337.jpg
# ✅ Saved CV2 image: cv2_noisy_337.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_337.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_337.jpg
# ✅ Saved PIL image: aug_pil_357_b1.03_c0.99_col0.79.jpg
# ✅ Saved CV2 image: cv2_crop_0.8_358.jpg
# ✅ Saved CV2 image: cv2_crop_0.6_358.jpg
# ✅ Saved CV2 image: cv2_scale_1.1_358.jpg
# ✅ Saved CV2 image: cv2_scale_1.3_358.jpg
# ✅ Saved CV2 image: cv2_flip_h_358.jpg
# ✅ Saved CV2 image: cv2_flip_v_358.jpg
# ✅ Saved CV2 image: cv2_rotate_15_358.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_358.jpg
# ✅ Saved CV2 image: cv2_rotate_30_358.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_358.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_358.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_358.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_358.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_358.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_358.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_358.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_358.jpg
# ✅ Saved CV2 image: cv2_noisy_358.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_358.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_358.jpg
# ✅ Saved PIL image: aug_pil_378_b1.22_c1.21_col0.95.jpg
# ✅ Saved CV2 image: cv2_crop_0.8_379.jpg
# ✅ Saved CV2 image: cv2_crop_0.6_379.jpg
# ✅ Saved CV2 image: cv2_scale_1.1_379.jpg
# ✅ Saved CV2 image: cv2_scale_1.3_379.jpg
# ✅ Saved CV2 image: cv2_flip_h_379.jpg
# ✅ Saved CV2 image: cv2_flip_v_379.jpg
# ✅ Saved CV2 image: cv2_rotate_15_379.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_379.jpg
# ✅ Saved CV2 image: cv2_rotate_30_379.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_379.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_379.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_379.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_379.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_379.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_379.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_379.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_379.jpg
# ✅ Saved CV2 image: cv2_noisy_379.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_379.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_379.jpg
# ✅ Saved PIL image: aug_pil_399_b1.11_c0.84_col1.15.jpg
# ✅ Saved CV2 image: cv2_crop_0.8_400.jpg
# ✅ Saved CV2 image: cv2_crop_0.6_400.jpg
# ✅ Saved CV2 image: cv2_scale_1.1_400.jpg
# ✅ Saved CV2 image: cv2_scale_1.3_400.jpg
# ✅ Saved CV2 image: cv2_flip_h_400.jpg
# ✅ Saved CV2 image: cv2_flip_v_400.jpg
# ✅ Saved CV2 image: cv2_rotate_15_400.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_400.jpg
# ✅ Saved CV2 image: cv2_rotate_30_400.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_400.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_400.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_400.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_400.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_400.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_400.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_400.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_400.jpg
# ✅ Saved CV2 image: cv2_noisy_400.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_400.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_400.jpg
# ✅ Saved PIL image: aug_pil_420_b0.93_c0.77_col0.84.jpg
# ✅ Saved CV2 image: cv2_crop_0.8_421.jpg
# ✅ Saved CV2 image: cv2_crop_0.6_421.jpg
# ✅ Saved CV2 image: cv2_scale_1.1_421.jpg
# ✅ Saved CV2 image: cv2_scale_1.3_421.jpg
# ✅ Saved CV2 image: cv2_flip_h_421.jpg
# ✅ Saved CV2 image: cv2_flip_v_421.jpg
# ✅ Saved CV2 image: cv2_rotate_15_421.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_421.jpg
# ✅ Saved CV2 image: cv2_rotate_30_421.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_421.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_421.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_421.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_421.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_421.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_421.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_421.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_421.jpg
# ✅ Saved CV2 image: cv2_noisy_421.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_421.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_421.jpg
# ✅ Saved PIL image: aug_pil_441_b1.20_c1.19_col1.10.jpg
# ✅ Saved CV2 image: cv2_crop_0.8_442.jpg
# ✅ Saved CV2 image: cv2_crop_0.6_442.jpg
# ✅ Saved CV2 image: cv2_scale_1.1_442.jpg
# ✅ Saved CV2 image: cv2_scale_1.3_442.jpg
# ✅ Saved CV2 image: cv2_flip_h_442.jpg
# ✅ Saved CV2 image: cv2_flip_v_442.jpg
# ✅ Saved CV2 image: cv2_rotate_15_442.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_442.jpg
# ✅ Saved CV2 image: cv2_rotate_30_442.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_442.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_442.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_442.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_442.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_442.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_442.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_442.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_442.jpg
# ✅ Saved CV2 image: cv2_noisy_442.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_442.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_442.jpg
# ✅ Saved PIL image: aug_pil_462_b1.14_c1.17_col0.96.jpg
# ✅ Saved CV2 image: cv2_crop_0.8_463.jpg
# ✅ Saved CV2 image: cv2_crop_0.6_463.jpg
# ✅ Saved CV2 image: cv2_scale_1.1_463.jpg
# ✅ Saved CV2 image: cv2_scale_1.3_463.jpg
# ✅ Saved CV2 image: cv2_flip_h_463.jpg
# ✅ Saved CV2 image: cv2_flip_v_463.jpg
# ✅ Saved CV2 image: cv2_rotate_15_463.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_463.jpg
# ✅ Saved CV2 image: cv2_rotate_30_463.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_463.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_463.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_463.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_463.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_463.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_463.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_463.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_463.jpg
# ✅ Saved CV2 image: cv2_noisy_463.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_463.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_463.jpg
# ✅ Saved PIL image: aug_pil_483_b0.84_c1.07_col0.81.jpg
# ✅ Saved CV2 image: cv2_crop_0.8_484.jpg
# ✅ Saved CV2 image: cv2_crop_0.6_484.jpg
# ✅ Saved CV2 image: cv2_scale_1.1_484.jpg
# ✅ Saved CV2 image: cv2_scale_1.3_484.jpg
# ✅ Saved CV2 image: cv2_flip_h_484.jpg
# ✅ Saved CV2 image: cv2_flip_v_484.jpg
# ✅ Saved CV2 image: cv2_rotate_15_484.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_484.jpg
# ✅ Saved CV2 image: cv2_rotate_30_484.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_484.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_484.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_484.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_484.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_484.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_484.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_484.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_484.jpg
# ✅ Saved CV2 image: cv2_noisy_484.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_484.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_484.jpg
# ✅ Saved PIL image: aug_pil_504_b1.02_c0.85_col1.20.jpg
# ✅ Saved CV2 image: cv2_crop_0.8_505.jpg
# ✅ Saved CV2 image: cv2_crop_0.6_505.jpg
# ✅ Saved CV2 image: cv2_scale_1.1_505.jpg
# ✅ Saved CV2 image: cv2_scale_1.3_505.jpg
# ✅ Saved CV2 image: cv2_flip_h_505.jpg
# ✅ Saved CV2 image: cv2_flip_v_505.jpg
# ✅ Saved CV2 image: cv2_rotate_15_505.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_505.jpg
# ✅ Saved CV2 image: cv2_rotate_30_505.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_505.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_505.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_505.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_505.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_505.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_505.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_505.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_505.jpg
# ✅ Saved CV2 image: cv2_noisy_505.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_505.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_505.jpg
# ✅ Saved PIL image: aug_pil_525_b1.13_c1.09_col0.74.jpg
# ✅ Saved CV2 image: cv2_crop_0.8_526.jpg
# ✅ Saved CV2 image: cv2_crop_0.6_526.jpg
# ✅ Saved CV2 image: cv2_scale_1.1_526.jpg
# ✅ Saved CV2 image: cv2_scale_1.3_526.jpg
# ✅ Saved CV2 image: cv2_flip_h_526.jpg
# ✅ Saved CV2 image: cv2_flip_v_526.jpg
# ✅ Saved CV2 image: cv2_rotate_15_526.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_526.jpg
# ✅ Saved CV2 image: cv2_rotate_30_526.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_526.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_526.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_526.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_526.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_526.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_526.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_526.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_526.jpg
# ✅ Saved CV2 image: cv2_noisy_526.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_526.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_526.jpg
# ✅ Saved PIL image: aug_pil_546_b0.75_c0.88_col1.12.jpg
# ✅ Saved CV2 image: cv2_crop_0.8_547.jpg
# ✅ Saved CV2 image: cv2_crop_0.6_547.jpg
# ✅ Saved CV2 image: cv2_scale_1.1_547.jpg
# ✅ Saved CV2 image: cv2_scale_1.3_547.jpg
# ✅ Saved CV2 image: cv2_flip_h_547.jpg
# ✅ Saved CV2 image: cv2_flip_v_547.jpg
# ✅ Saved CV2 image: cv2_rotate_15_547.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_547.jpg
# ✅ Saved CV2 image: cv2_rotate_30_547.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_547.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_547.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_547.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_547.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_547.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_547.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_547.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_547.jpg
# ✅ Saved CV2 image: cv2_noisy_547.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_547.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_547.jpg
# ✅ Saved PIL image: aug_pil_567_b0.78_c0.96_col0.98.jpg
# ✅ Saved CV2 image: cv2_crop_0.8_568.jpg
# ✅ Saved CV2 image: cv2_crop_0.6_568.jpg
# ✅ Saved CV2 image: cv2_scale_1.1_568.jpg
# ✅ Saved CV2 image: cv2_scale_1.3_568.jpg
# ✅ Saved CV2 image: cv2_flip_h_568.jpg
# ✅ Saved CV2 image: cv2_flip_v_568.jpg
# ✅ Saved CV2 image: cv2_rotate_15_568.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_568.jpg
# ✅ Saved CV2 image: cv2_rotate_30_568.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_568.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_568.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_568.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_568.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_568.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_568.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_568.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_568.jpg
# ✅ Saved CV2 image: cv2_noisy_568.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_568.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_568.jpg
# ✅ Saved PIL image: aug_pil_588_b0.85_c1.29_col1.15.jpg
# ✅ Saved CV2 image: cv2_crop_0.8_589.jpg
# ✅ Saved CV2 image: cv2_crop_0.6_589.jpg
# ✅ Saved CV2 image: cv2_scale_1.1_589.jpg
# ✅ Saved CV2 image: cv2_scale_1.3_589.jpg
# ✅ Saved CV2 image: cv2_flip_h_589.jpg
# ✅ Saved CV2 image: cv2_flip_v_589.jpg
# ✅ Saved CV2 image: cv2_rotate_15_589.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_589.jpg
# ✅ Saved CV2 image: cv2_rotate_30_589.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_589.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_589.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_589.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_589.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_589.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_589.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_589.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_589.jpg
# ✅ Saved CV2 image: cv2_noisy_589.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_589.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_589.jpg
# ✅ Saved PIL image: aug_pil_609_b1.25_c1.14_col1.10.jpg
# ✅ Saved CV2 image: cv2_crop_0.8_610.jpg
# ✅ Saved CV2 image: cv2_crop_0.6_610.jpg
# ✅ Saved CV2 image: cv2_scale_1.1_610.jpg
# ✅ Saved CV2 image: cv2_scale_1.3_610.jpg
# ✅ Saved CV2 image: cv2_flip_h_610.jpg
# ✅ Saved CV2 image: cv2_flip_v_610.jpg
# ✅ Saved CV2 image: cv2_rotate_15_610.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_610.jpg
# ✅ Saved CV2 image: cv2_rotate_30_610.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_610.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_610.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_610.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_610.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_610.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_610.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_610.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_610.jpg
# ✅ Saved CV2 image: cv2_noisy_610.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_610.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_610.jpg
# ✅ Saved PIL image: aug_pil_630_b1.24_c1.30_col1.10.jpg
# ✅ Saved CV2 image: cv2_crop_0.8_631.jpg
# ✅ Saved CV2 image: cv2_crop_0.6_631.jpg
# ✅ Saved CV2 image: cv2_scale_1.1_631.jpg
# ✅ Saved CV2 image: cv2_scale_1.3_631.jpg
# ✅ Saved CV2 image: cv2_flip_h_631.jpg
# ✅ Saved CV2 image: cv2_flip_v_631.jpg
# ✅ Saved CV2 image: cv2_rotate_15_631.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_631.jpg
# ✅ Saved CV2 image: cv2_rotate_30_631.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_631.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_631.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_631.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_631.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_631.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_631.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_631.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_631.jpg
# ✅ Saved CV2 image: cv2_noisy_631.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_631.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_631.jpg
# ✅ Saved PIL image: aug_pil_651_b1.04_c0.88_col1.23.jpg
# ✅ Saved CV2 image: cv2_crop_0.8_652.jpg
# ✅ Saved CV2 image: cv2_crop_0.6_652.jpg
# ✅ Saved CV2 image: cv2_scale_1.1_652.jpg
# ✅ Saved CV2 image: cv2_scale_1.3_652.jpg
# ✅ Saved CV2 image: cv2_flip_h_652.jpg
# ✅ Saved CV2 image: cv2_flip_v_652.jpg
# ✅ Saved CV2 image: cv2_rotate_15_652.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_652.jpg
# ✅ Saved CV2 image: cv2_rotate_30_652.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_652.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_652.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_652.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_652.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_652.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_652.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_652.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_652.jpg
# ✅ Saved CV2 image: cv2_noisy_652.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_652.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_652.jpg

# %%
import os

target_folder = r"/content/drive/MyDrive/Tea Augmentation/Output"
expected_count = 500

# Count .jpg images in the folder
image_count = len([
    f for f in os.listdir(target_folder)
    if f.lower().endswith('.jpg')
])

print(f"✅ Found {image_count} .jpg images in: {target_folder}")

if image_count == expected_count:
    print("🎉 Folder has exactly 500 images.")
elif image_count < expected_count:
    print(f"⚠️ Folder has fewer images than expected ({expected_count - image_count} missing).")
else:
    print(f"⚠️ Folder has more images than expected ({image_count - expected_count} extra).")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-389088563.py in <cell line: 0>()
#       6 # Count .jpg images in the folder
#       7 image_count = len([
# ----> 8     f for f in os.listdir(target_folder)
#       9     if f.lower().endswith('.jpg')
#      10 ])
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/Tea Augmentation/Output'

# %%
import os

# Path to the main dataset folder containing 10 class subfolders
main_dataset_folder = r"/content/drive/MyDrive/Tea Augmentation"  # Change this as needed

# List of 10 class names (folder names inside main folder)
class_names = [
    "Citruspot", "Early_Mild_Spotting", "Fungal", "Healthy", "Healthy_Mildly",
    "Healthy_Yellowing", "Mild_Edge__Damage", "Senescent", "Slightly_Diseased", "Wrinkled_Leaf"
]

print("📊 Image count per class:\n")

# Loop through each class folder and count .jpg images
for class_name in class_names:
    class_path = os.path.join(main_dataset_folder, class_name)

    if not os.path.isdir(class_path):
        print(f"❌ {class_name} - Folder not found: {class_path}")
        continue

    jpg_count = len([
        f for f in os.listdir(class_path)
        if f.lower().endswith('.jpg')
    ])

    print(f"✅ {class_name}: {jpg_count} .jpg images")
# Out:
# 📊 Image count per class:
#
# ❌ Citruspot - Folder not found: /content/drive/MyDrive/Hi/Citruspot
# ✅ Early_Mild_Spotting: 500 .jpg images
# ✅ Fungal: 500 .jpg images
# ✅ Healthy: 500 .jpg images
# ✅ Healthy_Mildly: 500 .jpg images
# ✅ Healthy_Yellowing: 500 .jpg images
# ✅ Mild_Edge__Damage: 500 .jpg images
# ✅ Senescent: 500 .jpg images
# ✅ Slightly_Diseased: 500 .jpg images
# ✅ Wrinkled_Leaf: 500 .jpg images
